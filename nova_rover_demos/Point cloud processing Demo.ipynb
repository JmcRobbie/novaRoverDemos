# %% [markdown]
# This notebook will briefly demonstrate the point cloud processing/ generating class.

# %%
from point_cloud_processing.ptcloudgen import PointCloudGen

# %%
size = [(0,1),(0,2),(0,5)] ## Size of data read in

# %%
cld = PointCloudGen(size,7) ## Generating class instance with default number of points and 4 features
cld.gaussian_cloud()
cld.get_occupancy_grid(0.05,0.05) ## 5cm grid resolution
cld.plot_occupancy_grid()
cld.plot_cloud()

# %% [markdown]
# ### Gradient method for identifying sharp non-traversible obstacles.
# This part demonstrates a new section of the point cloud processing, utilising a numerical vector derivitive being computed across the array and then using that to estimate the traversibility or otherwise of any given point on the grid.

# %%
cld.meanHeightGenerator(0.05,0.05)
cld.gradientComputation(0.05,0.05)
cld.plot_gradient_grid()
